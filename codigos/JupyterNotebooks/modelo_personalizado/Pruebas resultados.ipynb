# %% [markdown]
# # Pruebas de similitud con modelo personalizado

# %%
from gensim.models import KeyedVectors
from pprint import pprint
import pandas as pd
from statistics import mean
import spacy

# %% [markdown]
# #### Cargamos nuestro modelo personalizado

# %%
model = KeyedVectors.load_word2vec_format("modelo.txt", binary = False)

# %% [markdown]
# #### Importamos nuestros datos y etablecemos nuestra frase modelo

# %%
dataset = pd.read_csv("Datos-primaria-secundaria.csv")
model_str = "que mi hermanito grita mucho"

# %%
def docs_to_lists(docs):
    """
    Recibe una lista de strings y regresa
    para cada string una lista limpia
    sin stopwords o puntuaciones para usar
    entrenar Word2Vec.
    """
    temp_nlp = spacy.load("es_core_news_lg")
    doc_corp = []
    for doc in docs:
        clean_doc = []
        for word in temp_nlp(doc):
            if not(word.is_stop or word.is_punct or len(word) == 1):
                clean_doc.append(word.text)
        print(clean_doc)
        doc_corp.append(clean_doc)
    return doc_corp

def doc_to_str(clean_docs):
    """
    Recibe una lista de listas (de la func
    docs_to_lists) y las convierte en un string.
    """
    str_docs = []
    for doc in clean_docs:
        str_docs.append(" ".join(doc))
    return str_docs

def clean_docs(docs):
    """
    Recibe una lista de strings y las limpia de
    puntuaciones y stopwords
    """
    return doc_to_str(docs_to_lists(docs))

# %%
docs_str = dataset.iloc[:,0].values.tolist()
docs = docs_to_lists(docs_str)
# Out:
# ['canta']
# ['hermano', 'grita']
# ['NS']
# ['hermano', 'llora']
# ['travieso', 'llora']
# ['hemanos', 'gritan']
# ['hermano', 'grita']
# ['gritamos']
# ['irritante', 'llora']
# ['hermano', 'grita']
# ['hermano', 'griton']
# ['hermano', 'grita']
# ['NS']
# ['hermano', 'grita']
# ['grita', 'reir']
# ['hermano', 'chillon']
# ['grita']
# ['grita']
# ['lenguaje', 'literal']
# ['hermano', 'gritando']
# ['griton']
# ['hermano', 'pelota', 'grita']
# ['enoja', 'empieza', 'gritar']
# ['hermano', 'grita']
# ['hermano', 'grita']
# []
# ['grita', 'fuerte']
# ['grita']
# ['grita', 'hermano']
# ['asusta', 'enojona', 'grita', 'furia']
# ['lloron', 'pelota', 'gritos']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['bota']
# ['hermano', 'gritando']
# ['grita']
# ['aburrido']
# ['hermano', 'mayoria', 'grita', 'llora']
# ['hermanito', 'pequeno', 'grita']
# ['hermanito', 'grita']
# ['grita']
# ['chilla']
# ['gritando']
# ['hermanas', 'enojan']
# ['hermano', 'travieso']
# ['grita']
# ['hermano', 'griton']
# ['escandaloso']
# ['llora']
# ['hermano', 'grita']
# ['pelota', 'inflada']
# ['grita']
# ['persona', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['nino', 'griton']
# ['hermanito', 'grita']
# ['griton']
# ['hermano', 'grita']
# ['hermano', 'griton']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['gordito', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'griton']
# ['expresa', 'llora']
# ['gordo', 'grita']
# ['hermano', 'grita']
# ['grita']
# ['rato', 'grita']
# ['hermano', 'persona', 'gritona']
# ['hermano', 'grita']
# ['grita']
# ['hermano', 'grita']
# ['entendi']
# ['enojon']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['NS']
# ['bebes', 'lloran']
# ['hermano', 'grita']
# ['hermano', 'cabeza', 'redonda', 'grita']
# ['grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'bebe', 'chilla', 'grita']
# ['hermano', 'grita']
# ['hermano', 'salta', 'grita']
# ['grita']
# ['hermano', 'grita']
# ['hermanito', 'grita', 'suelta', 'pelota']
# ['hermanito', 'grita', 'pelotas', 'pelotas']
# ['grita']
# ['circular', 'comelona']
# ['hermano', 'grita']
# ['dormido']
# ['grita']
# ['hermana', 'pelota', 'risa']
# ['NS']
# ['hermanito', 'llora', 'grita']
# ['gritona']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'griton']
# ['llora', 'grita', 'necesita']
# ['divertido', 'grita']
# ['gritona']
# ['gordito', 'griton']
# ['grita']
# ['grita']
# []
# ['bebe', 'meten', 'ladrillo', 'boca', 'callarlo']
# ['grita']
# ['grita']
# ['guste', 'decirle']
# ['grita']
# ['NS']
# ['pelota', 'gritona', 'commo', 'hermano']
# ['grita']
# ['hermanito', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'rueda']
# ['hermanito', 'grita']
# ['griton', 'juega', 'pelota']
# ['jugueton', 'grita']
# ['hermano', 'grita']
# ['hermanito', 'satltara', 'saltara', 'sentido']
# ['hermano', 'gritar']
# ['juega', 'pelota', 'grita']
# ['hermano', 'grita']
# ['grita']
# ['pelotas']
# ['grita']
# ['rebota', 'suena', 'grito']
# ['hermanito', 'grita']
# ['pelota', 'gritos', 'bebes', 'lloran', 'gritan', 'eructan']
# ['hermano', 'grita', 'gusta', 'saltar']
# ['chilla']
# ['hermano', 'grita', 'alto']
# ['grita']
# ['refiere', 'hermanito', 'griton', 'grita']
# ['hermano', 'grita', 'llora']
# ['hermano', 'grita']
# ['encanta', 'gritar']
# ['griton']
# ['hermano', 'chillon', 'griton']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['grita']
# ['hermanito', 'grita', 'eleva', 'pelota']
# ['hermano', 'grita']
# ['hermanito', 'grita', 'redondo']
# ['hermano', 'pasa', 'gritando']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'llora']
# ['hermano', 'grita']
# ['llora', 'molesta']
# ['hermano', 'grita', 'fuerte', 'diario']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['seguramente', 'bebe', 'bebes', 'gritan', 'lloran']
# ['grita']
# ['hermano', 'grita']
# ['hermanito', 'griton', 'chillon', 'comelon', 'etc.']
# ['grita']
# ['hermano', 'travieso', 'grita']
# ['hermano', 'grita', 'pelotas']
# ['hermano', 'grita', 'llora']
# ['hermanita', 'grita']
# ['grita', 'grita']
# ['nino', 'llora', 'grita', 'caso']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'enojon']
# ['hermano', 'grita']
# ['escandalosa']
# ['pasa', 'gritando']
# ['grita']
# ['hermano', 'gritando']
# ['griton']
# ['llora', 'grita', 'berrinches']
# ['hermanito', 'nino']
# ['grita']
# ['hermano', 'griton']
# ['hermano', 'chico', 'razonar', 'resuelve', 'gritos']
# ['hermana', 'persona', 'gritos']
# ['hermana', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['llora', 'grita']
# ['pelota', 'gritos', 'namas', 'pelota', 'jugar']
# ['hermanito', 'triste']
# ['hermano', 'pequeno', 'grita', 'muchisimo']
# ['hermanito', 'grita']
# ['hermano', 'grita']
# ['hermano', 'deja', 'gritar']
# ['llora', 'grita']
# ['hermanito', 'bebe', 'grita']
# ['hermano', 'grita']
# ['pelota']
# ['hermano', 'grita']
# ['hermano', 'pasa', 'gritando']
# ['ninos', 'chicos', 'gritan']
# ['latoso']
# ['gritar']
# ['hermanito', 'grita']
# ['bebe', 'tambiengrita', 'grita']
# ['hermano', 'griton']
# []
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['grita']
# ['NS']
# ['das', 'empieza', 'llorar', 'gritar']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'nino', 'griton']
# ['grita']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['pelota', 'gritos']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['pelota', 'gritos']
# ['hermano', 'griton']
# []
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermanito', 'pelota', 'gritos']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermanito', 'chiquito', 'bebe', 'llora', 'comida', 'leche', 'cambien', 'panal']
# ['hermano', 'grita']
# ['ninos', 'pequenos', 'gritan']
# ['grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'gordito', 'pelota', 'hermano', 'grita']
# ['hermanito', 'grita']
# ['hermanito', 'grita']
# ['grita']
# ['hermanito', 'pelota', 'grita']
# ['grita', 'agrega', 'pelota']
# ['hermano', 'grita']
# ['grita']
# ['hermano', 'llora']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['qu', 'hermano', 'grita']
# ['hermano', 'grita']
# ['grita']
# ['grita']
# ['hermano', 'grita']
# ['hermano', 'llora']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['NS']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'pelota', 'gritos']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermanito', 'pelota', 'gritos']
# ['presion']
# ['pelota', 'gritos']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermana', 'pelota', 'gritos']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'pelota', 'grita']
# ['grita']
# ['grita', 'rato']
# ['grita']
# ['hermano', 'grita']
# ['hermano', 'grita', 'llora']
# ['qu', 'hermano', 'grita']
# ['fer', 'rovin']
# ['grita']
# ['gritona']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['grita']
# ['hermano', 'pelota', 'grita', 'ayuden']
# ['grita']
# ['nino', 'gritando']
# ['gordito', 'grita']
# ['hermanito', 'grita']
# ['hermano', 'grita']
# ['grita', 'hermanitp', 'pelota']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['gordito', 'grita']
# ['grita']
# ['hermano', 'grita']
# ['grita']
# ['grita', 'feliz']
# ['gusta', 'jugar', 'futbol', 'pelota', 'suena']
# ['hermano', 'grita']
# ['grita', 'juega', 'grita']
# ['griton', 'latoso']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermanito', 'grita', 'pelota', 'gritos']
# ['grita', 'pelota', 'rebotar', 'suena']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['grita']
# ['chilla']
# ['grita']
# ['hermanito', 'griton']
# ['gritando']
# ['granos']
# ['hermano', 'grita']
# ['grita', 'travieso']
# ['berrinche', 'emocion']
# ['hermano', 'grita', 'simplemente', 'llora']
# ['hermano', 'gordito', 'grita']
# ['pelota', 'brinca', 'grita']
# ['gusta', 'rebote', 'pelota']
# ['hermano', 'grita']
# ['llora', 'pequeno']
# ['hermanito', 'grita']
# ['reganan', 'hemanos']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['grita']
# ['hermano', 'griton']
# ['hermanito', 'guardado', 'gritos']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'griton']
# ['hermano', 'escandaloso']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['puedes', 'hermanito', 'gordito', 'grita']
# ['hermano', 'rato', 'grita']
# ['grita', 'llora']
# ['hermano', 'grita', 'constantemente']
# ['hermano', 'menor', 'grita']
# ['hermano', 'grita']
# ['hermanito', 'grita', 'casa']
# ['hermano', 'grita']
# ['hermano', 'griton']
# ['gritar']
# ['grita', 'parar', 'pelota']
# ['ninos', 'chiquitos', 'berrinche']
# ['hermano', 'griton']
# ['hermanito', 'grita']
# ['hermanito', 'griton']
# ['grita']
# ['hermanito', 'berrinches']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'brinca', 'llora', 'gritos']
# ['grita']
# ['pelota', 'ruido', 'pelota', 'gritos']
# ['hermanito', 'gordo', 'gritos']
# ['hermano', 'gritando', 'saltando']
# ['hermano', 'grita']
# ['hermanito', 'grita', 'casa']
# ['hermano', 'gustan', 'gritos']
# ['hermano', 'grita']
# ['hermano', 'ruidoso']
# ['persona', 'gritar']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'griton']
# ['hermanito', 'llora', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita', 'pelota', 'entiendo']
# ['hermano', 'grita']
# ['hermano', 'gritando', 'pelota', 'rebota']
# ['hermanito', 'latoso']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['llorar', 'quejarse', 'llorar', 'rato', 'gritando']
# ['ruido']
# ['hermano', 'grita', 'normal']
# ['persona', 'gritona']
# ['nino', 'grita']
# ['griton']
# ['grita']
# ['hermano', 'griton']
# ['hermanito', 'sube', 'voz']
# ['refiere', 'hermano', 'grita', 'poeta', 've', 'mundo', 'pelotas']
# ['talves', 'hermano', 'grita']
# ['grita']
# ['silencio', 'jajajajaja']
# ['hermano', 'gritar', 'pelota', 'pelos']
# ['pequeno', 'lata']
# ['yoron']
# ['hermano', 'compran', 'pone', 'gritar']
# ['hermano', 'pelota', 'grita']
# ['grita']
# ['abla', 'grita']
# ['nina', 'pasa', 'llorando', 'asiendo', 'berrinche']
# ['grita']
# ['grita']
# ['hermano', 'grita']
# ['grita']
# ['voz', 'baja']
# ['grita']
# ['hermanito', 'grita']
# ['gordito', 'grita']
# ['hermano', 'nino', 'pequeno']
# ['gritos']
# ['exagera', 'berrinche']
# ['nolo', 'xd']
# ['llora']
# ['grita']
# ['dibertido']
# ['tocan', 'grito']
# ['hermanito', 'energias', 'gritar']
# ['hermanito', 'gritar']
# ['hermano', 'grita']
# ['hermano', 'alguien', 'grita']
# ['pegan', 'pone', 'gritar']
# ['pasa', 'gritando', 'pensativo', 'ajajjajaj']
# ['grita']
# ['hermano', 'etsa', 'gordo', 'pasa', 'gritando']
# ['frita']
# ['enpieza', 'gritar']
# ['chilla']
# []
# ['hermano', 'redondo', 'grita']
# ['hermanos', 'lloran']
# []
# ['qu', 'hermano', 'pasa', 'gritando', 'osea', 'desastroso']
# ['explica', 'hermano', 'grita', 'inquieto']
# ['13fg']
# ['griton']
# ['hermanito', 'gordo', 'grita']
# ['refiere', 'hermanito', 'grita']
# ['hermano', 'grita']
# ['hermano', 'chico', 'grita']
# ['grita', 'llora', 'pelota', 'gritos']
# ['hermano', 'quejar', 'rato', 'anda', 'gritando']
# ['nino', 'grita']
# ['grita']
# ['hermano', 'gritar', 'pelotas', 'pelos']
# ['grita']
# ['lloron']
# ['sentimientos']
# ['grita']
# ['hermano', 'grita', 'desespera', 'frase', 'pelota', 'gritos', 'supongo']
# ['grita']
# ['hermanitos', 'molestones']
# ['hermano', 'pasa', 'gritando', 'molesta']
# ['hermano', 'grita']
# ['grita']
# ['griton']
# ['grita']
# ['gordo', 'gita']
# ['ruidoso']
# ['lata']
# ['hermanito', 'grita']
# ['gryta', 'ermanito']
# ['hermanito', 'grita']
# ['hermano', 'grita']
# ['fastidioso']
# ['pelota', 'mu', 'enojada']
# ['see']
# ['platicon']
# ['berrinchudo']
# ['hermanito', 'nino', 'gritos']
# ['xk', 'hermano', 'simpre', 'grita']
# ['hermano', 'gordo', 'grita']
# ['hermano', 'griton']
# ['alguien', 'griton']
# ['hermano', 'inquieto']
# ['ninos', 'escandalosos']
# ['forma', 'expresar', 'palabras', 'metaforicas']
# ['hermano', 'persona', 'grita']
# ['grita', 'salta']
# ['griton', 'molesto']
# ['significa', 'reclama', 'llora']
# ['hermanito', 'grite']
# ['unde', 'llanto']
# ['hermano', 'grita']
# ['hermanito', 'grita']
# ['poequ', 'griton']
# ['grita']
# ['grita']
# ['llora']
# ['nino', 'pasa', 'gritando', 'llorando']
# ['chillan', 'gritan', 'exageran']
# ['mama', 'persona', 'gritona']
# ['entisende']
# ['pasa', 'gritando']
# ['grita']
# ['hermano', 'nino', 'grita']
# ['ruidoso']
# ['maquina', 'alguien', 'grita']
# ['pirhhhhgvfriufueiituj']
# ['llora']
# ['puen', 'hermana', 'grita']
# ['NS']
# ['and', 'fort']
# ['grita']
# ['grita']
# ['hermano', 'grita']
# ['grita']
# ['hermanito', 'gritando', 'ruido']
# ['hermano', 'persona', 'ruidosa']
# ['grita']
# ['gritando', 'parar']
# ['hermanito', 'griton', 'hermanita', 'loco']
# ['grita']
# ['hermano', 'grita']
# ['grita']
# ['hermano', 'energia']
# ['pequeno', 'grita']
# ['pequeno', 'grita']
# ['gritona']
# ['gritar']
# ['grita']
# ['hermano', 'grita']
# ['parecer', 'hermano', 'grita', 'entiende', 'metafora', 'pelota']
# ['hermano', 'grita']
# ['refiere', 'persona', 'grita']
# ['hermano', 'escandalo']
# ['hecha', 'relajo']
# ['loco']
# ['grita']
# ['hermano', 'imperactivo']
# ['hermano', 'pasa', 'gritando']
# ['escandalo']
# ['alborotado']
# ['pasa', 'gritando']
# ['gordito', 'grita']
# ['grita']
# ['hermanito', 'gordito', 'griton']
# ['grita']
# ['hermano', 'gritando']
# ['gritar']
# ['hermano', 'grita', 'sale', 'circulo']
# ['humano', 'gordo', 'chillar']
# ['grita']
# ['grita']
# ['hermano', 'pasa', 'gritando']
# ['grita', 'lata']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['grita', 'hablar', 'grita']
# ['nino', 'nino', 'grita']
# ['hermano', 'grita', 'pelota', 'botando']
# ['alguien', 'grita']
# ['grita']
# ['hermano', 'quejumbroso', 'lloron']
# ['pasa', 'gritando']
# ['sobrepeso']
# ['hablando', 'grtando']
# ['nino', 'gordo', 'grita', 'tono', 'voz', 'fuertealto']
# ['grita']
# []
# ['grita']
# ['hermano', 'gritando', 'conjunto', 'gritos']
# ['grita']
# ['grita']
# ['hermano', 'grita']
# ['hermano', 'griton']
# ['hermano', 'grita', 'ruido']
# ['grita']
# ['grita']
# ['grita']
# ['gritando']
# ['mueve', 'pelota', 'ruidoso']
# ['hermano', 'chiquito', 'grita']
# ['hermano', 'grita']
# ['NS']
# ['significa', 'nino', 'chillon', 'normalmente', 'desespera', 'grita']
# ['hermano', 'grita', 'gordo']
# ['hermano', 'griton']
# ['grita']
# ['hermano', 'nino', 'grita']
# ['grita', 'exceso']
# ['hermano', 'alguien', 'gritar', 'hablar']
# ['hermanito', 'griton', 'llora', 'llorona']
# ['alguien', 'grita']
# ['hermano', 'grita']
# ['hermano', 'representa', 'infante', 'plena', 'etapa', 'inocencia', 'escandalo']
# ['hermano', 'grita']
# ['grita']
# ['deja', 'gritar']
# ['escandalo', 'quedar', 'quieto']
# ['grita']
# ['irritanto']
# ['hermano', 'gordito', 'redondo', 'constantemente', 'gritando']
# ['machina', 'gritar']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['deja', 'hablar']
# ['nino', 'gordito', 'pasa', 'gritando']
# ['ninos', 'demasiados', 'inquietos', 'ruidosos']
# ['hermanito', 'grita']
# ['hermando', 'nino', 'travieso']
# ['hermano', 'grita']
# ['hermanito', 'griton']
# ['llorando', 'gritando']
# ['dolor', 'cabeza']
# ['invalida', 'sistema']
# ['grita']
# ['berrinche', 'grita']
# ['nino', 'inquieto']
# ['hermanito', 'grita']
# ['hermano', 'encanta', 'cantar']
# ['grita']
# ['ternura']
# ['gordito', 'griton']
# ['ruidosos']
# ['grita']
# ['hermano', 'grita']
# ['hermanito', 'ruidoso']
# ['hermanito', 'estresa', 'bes', 'grita']
# ['hermanito', 'grita']
# ['nino', 'ruidoso']
# ['ermano', 'grita']
# ['hermano', 'grita', 'llora', 'autor@', 'refiere', 'sentido', 'literario']
# ['grita']
# ['ninos', 'pequenos', 'regular', 'gritan']
# ['chillon']
# ['bb']
# ['grita']
# ['hermanito', 'grita']
# ['hermano', 'representa', 'pelota', 'grita']
# ['grita', 'fuerte']
# ['llora', 'grita']
# ['pelota']
# ['hermano', 'persona', 'grita']
# ['nino']
# ['grita']
# ['hermanito', 'grita']
# ['hermano', 'grita']
# ['inquieto']
# ['asu', 'hermano', 'gustan', 'grillos', 'alv']
# ['grita']
# ['hermono', 'grita']
# ['gordo', 'gusta', 'cantar']
# ['hermano', 'grita']
# ['grita']
# ['hermano', 'grita', 'grita', 'parar', 'sentido']
# ['ninos', 'energeticos', 'tienden', 'gritar']
# ['osea', 'hermano', 'grita']
# ['hermano', 'llorando', 'gritando']
# ['ruido']
# ['bote', 'grito', 'hermano']
# ['hermano', 'pasa', 'gritando']
# ['mete', 'goles']
# ['hermanito', 'grita']
# ['hermano', 'pasa', 'gritando']
# ['grito']
# ['hermano', 'latoso']
# ['llega', 'gritar']
# ['gritos']
# ['hermano', 'grita', 'ase', 'esallar', 'alas', 'personas']
# ['fastidioso']
# ['grita']
# ['grande', 'grita']
# ['grita']
# ['pasa', 'gritando']
# ['hermana', 'grita']
# ['hermanito', 'griton']
# ['grita']
# ['refiere', 'hermano', 'persona', 'gritona']
# ['ninos', 'gritan']
# ['toso']
# ['gritano']
# ['hermano', 'bebe', 'grita', 'llora']
# ['gritando', 'hermano']
# ['hermanito', 'grita']
# ['hermanito', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita', 'metafora']
# ['entiendo', 'hermano', 'grita', 'refiere']
# ['refiere', 'hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'lloron', 'enojon', 'grita']
# ['qwee']
# ['regana', 'hermano', 'menor']
# ['persona', 'grita']
# ['alguien', 'pelota', 'mayoria', 'tratan', 'decirle', 'gordoa', 'supongo', 'hermano', 'gordo', 'griton']
# ['persona', 'inquieta']
# ['grita']
# ['mueve', 'ruido']
# ['cosa', 'altera', 'grita']
# ['quieta']
# ['hermanito', 'grita', 'casa']
# ['ami', 'entender', 'persona', 'referencia', 'pelota', 'hermano', 'inquieto']
# ['hermano', 'gusta', 'gritar', 'hablar', 'fuerte']
# ['fastidioso']
# ['grita']
# ['entiendo', 'nino', 'pelota', 'super', 'fantastica']
# ['ninos', 'gritan', 'pequenos']
# ['hermano', 'bola', 'pelos']
# ['lida', 'conmigom', 'parese', 'tierno', 'pelota', 'pelos', 'sister']
# ['hermanito', 'grita', 'imperactivo']
# ['hermano', 'grita']
# ['grita']
# ['nino', 'griton', 'juega', 'pelota']
# ['grita']
# ['nino', 'grita', 'expresa', 'comun', 'forma']
# ['hermano', 'griton']
# ['ththt']
# ['grita']
# ['moleta']
# ['apodo']
# ['hermano', 'grillos']
# ['grita', 'piensa', 'pelota']
# ['latoso']
# ['gordito', 'pasa', 'gritando']
# ['pasa', 'gritando']
# ['peota', 'quieren', 'grita']
# ['supongo', 'nino', 'grita', 'nino', 'anos']
# ['sobrina']
# ['hermanito', 'griton']
# ['hermano', 'grita']
# ['grita', 'hermano']
# ['hermanito', 'grita']
# ['refiere', 'hermana']
# ['hermano', 'grita', 'muho', 'bota', 'pelota']
# ['grita']
# ['pasa', 'gritando']
# ['hermano', 'grita', 'ruidoso']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'griton', 'escandaloso', 'travieso']
# ['hermano', 'gritando']
# ['hermano', 'nino', 'super', 'griton']
# ['hermanos', 'molestar', 'normalmente', 'peleas']
# ['hermano', 'grita', 'vuelve', 'constante']
# ['nino', 'llamar', 'atencion', 'gritos']
# ['hermano', 'grita']
# ['molesto', 'castroso']
# ['hermanito', 'grita']
# ['nino', 'gordito', 'pelota', 'grita']
# ['referencia', 'hermano', 'grita', 'hubieran', 'puesto', 'tipo', 'sobrante', 'pelota']
# ['griton']
# ['altera', 'rapido']
# ['grita']
# ['hermanito', 'nino', 'grita']
# ['hermano', 'grita']
# ['grita']
# ['deja', 'gritar']
# ['simplemente', 'hermano', 'persona', 'gritona', 'pelota', 'refiere', 'cabeza']
# ['gordo', 'gusta', 'gritar']
# ['hermano', 'grita']
# ['ninos', 'ruido']
# ['ruidoso']
# ['qiere']
# ['grita', 'rato']
# ['grita']
# ['gritando']
# ['hermano', 'pasa', 'gritando']
# ['persona', 'reganona', 'grita']
# ['latoso']
# ['hermano', 'grita']
# ['hermanito', 'griton', 'forma', 'pelota']
# ['gritando']
# ['hermano', 'expresivo']
# ['llora']
# ['grita']
# ['anda', 'brincando', 'gritando']
# ['hermano', 'grita']
# ['nino', 'grita']
# ['hermanito', 'grita']
# ['persona', 'gordita', 'grita']
# ['refiere', 'hermano', 'inquieto']
# ['nino', 'griton']
# ['persona', 'grita']
# ['hermanito', 'pequeno', 'deja', 'llorar', 'gritar', 'pasa']
# ['gritar', 'molestar']
# ['hermano', 'grita']
# ['persona', 'gorda', 'grita']
# ['grita', 'rebota']
# ['grita']
# ['cosa', 'llora', 'grita']
# ['pasa', 'gritando']
# ['talvez', 'sienpre', 'corriendo', 'em', 'paz']
# ['chiquito', 'grita']
# ['hermano', 'gritar', 'escandaloso']
# ['nino', 'griton']
# ['nino', 'griton']
# ['hermano', 'grita', 'pelota', 'ocupando', 'alternativa']
# ['hermano', 'escandaloso']
# ['rato', 'gritando']
# ['grita']
# ['calla']
# ['hermano', 'grita']
# ['grita']
# ['hermano', 'grita']
# ['lleno', 'gritos']
# ['llora', 'grita']
# ['describe', 'hermano', 'grita']
# ['grita']
# ['grita']
# ['hermano', 'menor', 'grita']
# ['lleno', 'gritos', 'listos', 'salir']
# ['molestando']
# ['escandaloso', 'ruidoso']
# ['hermano', 'griton', 'unico']
# ['significa', 'persona', 'grita']
# ['significa', 'hermano', 'escandaloso']
# ['refiere', 'hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['pequeno', 'llora', 'grita']
# ['grita', 'probablemente', 'menor']
# ['hermano', 'griton']
# ['nino', 'gordo', 'ruido']
# ['gritando']
# ['pq', 'espanta', 'facil', 'salta', 'tiemmpo', 'gfrita']
# ['grita', 'fuerte', 'grita']
# ['hermano', 'tiende', 'gritar']
# ['refieren', 'pelota', 'representa', 'hermano', 'hermano', 'grita', 'accion', 'representa', 'hermano']
# ['hermano', 'nino', 'pequeno', 'ninos', 'pequenos', 'gritan', 'berrinches', 'bebe', 'hermano', 'bebes', 'lloran']
# ['gordo', 'grita']
# ['pelota', 'significa', 'impratividad', 'osea', 'rebotar', 'gritos', 'representa', 'ruido']
# ['hermano', 'deja', 'gritar']
# ['gritan']
# ['grita', 'demaciado']
# ['nino', 'grita', 'continuo']
# ['significa', 'hermano', 'llora', 'gritos']
# ['hermano', 'griton']
# ['grita', 'llora', 'grita']
# ['hermano', 'desastroso', 'grita']
# ['hermano', 'autor', 'alguien', 'expresa', 'demandante']
# ['hermano', 'grita', 'pelota(salta', 'bota']
# ['escandaloso']
# ['hermano', 'grita']
# ['molesta', 'facilmente']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['pega', 'gritos']
# ['persona', 'grita']
# ['hermano', 'grita']
# ['alguien', 'gritar']
# ['hermanos', 'gritan', 'lloran', 'menores', 'casas', 'comparo', 'pelota']
# ['that', 'maybe', 'her', 'sister', 'always', 'screams', 'to', 'her']
# ['bebe', 'grita']
# ['gritando']
# ['deja', 'gritar']
# ['hermanito', 'grita']
# ['significar', 'hermano', 'ruidoso']
# ['grita']
# ['usando', 'palabra', 'pelota', 'ue', 'pensar', 'hermanito', 'simplemente', 'griton']
# ['nino', 'grita']

# %%
def similarity(str1, str2):
    """
    str1 debe ser una lista de las palabras
    str2 es la frase modelo
    regresa una lista de listas con las similitudes
    similarity(), wmdistance(), n_sim(), distance()
    en ese orden
    """
    #a = str1.split()
    b = str2.split()
    a = [word for word in str1 if word in model.vocab]
    b = [word for word in b if word in model.vocab]
    sims = []
    if not len(a) == 0:
        for word in a:
            temp = []
            for word2 in b:
                temp.append(model.similarity(word, word2))
            sims.append(mean(temp))
        sim = mean(sims)
        distance = []
        for word in a:
            temp = []
            for word2 in b:
                temp.append(model.distance(word, word2))
            distance.append(mean(temp))
        distance = mean(distance)
        wmdistance = model.wmdistance(a,b)
        n_sim = model.n_similarity(a,b)
    else:
        return (False, False, False, False)
    return sim, wmdistance, n_sim, distance

def list_similarity(ls, frase):
    similitudes = [similarity(i, frase) for i in ls]
    return similitudes

# %%
x = list_similarity(docs, model_str)
similarities = [i[0] for i in x]
wmdistances = [i[1] for i in x]
n_similarities = [i[2] for i in x]
distances = [i[3] for i in x]
x
# Out:
# [(False, False, False, False),
#  (0.22360355, 0.019130536618763582, 0.54872155, 0.7763964729383588),
#  (False, False, False, False),
#  (-0.08023764, 0.04211252331970074, -0.15989026, 1.080237640067935),
#  (-0.101670794, 0.0419367426332552, -0.20780554, 1.1016707923263311),
#  (0.07636154, 0.039953230366760864, 0.108274534, 0.9236384630203247),
#  (0.22360355, 0.019130536618763582, 0.54872155, 0.7763964729383588),
#  (False, False, False, False),
#  (-0.08552028, 0.04178141892800853, -0.13207121, 1.0855202786624432),
#  (0.22360355, 0.019130536618763582, 0.54872155, 0.7763964729383588),
#  (0.0031861067, 0.039237635033791886, -0.007655694, 0.9968138951808214),
#  (0.22360355, 0.019130536618763582, 0.54872155, 0.7763964729383588),
#  (False, False, False, False),
#  (0.22360355, 0.019130536618763582, 0.54872155, 0.7763964729383588),
#  (0.5221621, 0.020206093788146973, 0.77471304, 0.47783794440329075),
#  (-0.051960483, 0.03977283850598336, -0.1137906, 1.0519604831933975),
#  (0.5221621, 0.020206093788146973, 0.77471304, 0.47783794440329075),
#  (0.5221621, 0.020206093788146973, 0.77471304, 0.47783794440329075),
#  (False, False, False, False),
#  (-0.027698452, 0.0417961235492453, -0.07878118, 1.027698451653123),
#  (0.081327215, 0.03912271664053202, 0.11515425, 0.918672788888216),
#  (0.13579953, 0.02705119308465477, 0.4019607, 0.8642004877328873),
#  (0.053038348, 0.04047812430082821, 0.07066457, 0.9469616524875164),
#  (0.22360355, 0.019130536618763582, 0.54872155, 0.7763964729383588),
#  (0.22360355, 0.019130536618763582, 0.54872155, 0.7763964729383588),
#  (0.0031861067, 0.039237635033791886, -0.007655694, 0.9968138951808214),
#  (0.3196013, 0.01926831596029565, 0.7144275, 0.6803987224896749),
#  (0.22360355, 0.019130536618763582, 0.54872155, 0.7763964729383588),
#  (-0.040363945, 0.0425919198257681, -0.098065615, 1.0403639450669289),
#  (0.22360355, 0.019130536618763582, 0.54872155, 0.7763964729383588),
#  (-0.022286162, 0.04136412875211797, -0.02334173, 1.0222861617803574),
#  (0.22360355, 0.019130536618763582, 0.54872155, 0.7763964729383588),
#  (False, False, False, False),
#  (0.22360355, 0.019130536618763582, 0.54872155, 0.7763964729383588),
#  (0.22360355, 0.019130536618763582, 0.54872155, 0.7763964729383588),
#  (0.1387983, 0.03812025208232925, 0.19677371, 0.861201710999012),
#  (0.25859043, 0.01929728146526404, 0.5762817, 0.7414095802232623),
#  (0.22360355, 0.019130536618763582, 0.54872155, 0.7763964729383588),
#  (0.02363273, 0.0414141634410061, 0.03193845, 0.9763672705739737),
#  (0.0383844, 0.04049920777966861, 0.089530885, 0.9616155984501044),
#  (False, False, False, False),
#  (0.2806274, 0.019420171721100807, 0.5936869, 0.7193726068362594),
#  (0.019558098, 0.04152206001244486, 0.015338458, 0.980441901832819),
#  (0.056686267, 0.040757008255310354, 0.10850576, 0.9433137332089245),
#  (0.5221621, 0.0, 1.0, 0.47783794440329075),
#  (-0.052728236, 0.040467408014999706, -0.11098041, 1.052728233858943),
#  (0.5221621, 0.020206093788146973, 0.77471304, 0.47783794440329075),
#  (0.1878936, 0.027702236505195835, 0.38791072, 0.8121064168711504),
#  (0.25847167, 0.019352493600457907, 0.5754827, 0.7415283480659127)]

# %%
clean_doc_str = clean_docs(docs_str)
clean_doc_str
# Out:
# ['canta']
# ['hermano', 'grita']
# ['NS']
# ['hermano', 'llora']
# ['travieso', 'llora']
# ['hemanos', 'gritan']
# ['hermano', 'grita']
# ['gritamos']
# ['irritante', 'llora']
# ['hermano', 'grita']
# ['hermano', 'griton']
# ['hermano', 'grita']
# ['NS']
# ['hermano', 'grita']
# ['grita', 'reir']
# ['hermano', 'chillon']
# ['grita']
# ['grita']
# ['lenguaje', 'literal']
# ['hermano', 'gritando']
# ['griton']
# ['hermano', 'pelota', 'grita']
# ['enoja', 'empieza', 'gritar']
# ['hermano', 'grita']
# ['hermano', 'grita']
# []
# ['grita', 'fuerte']
# ['grita']
# ['grita', 'hermano']
# ['asusta', 'enojona', 'grita', 'furia']
# ['lloron', 'pelota', 'gritos']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['bota']
# ['hermano', 'gritando']
# ['grita']
# ['aburrido']
# ['hermano', 'mayoria', 'grita', 'llora']
# ['hermanito', 'pequeno', 'grita']
# ['hermanito', 'grita']
# ['grita']
# ['chilla']
# ['gritando']
# ['hermanas', 'enojan']
# ['hermano', 'travieso']
# ['grita']
# ['hermano', 'griton']
# ['escandaloso']
# ['llora']
# ['hermano', 'grita']
# ['pelota', 'inflada']
# ['grita']
# ['persona', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['nino', 'griton']
# ['hermanito', 'grita']
# ['griton']
# ['hermano', 'grita']
# ['hermano', 'griton']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['gordito', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'griton']
# ['expresa', 'llora']
# ['gordo', 'grita']
# ['hermano', 'grita']
# ['grita']
# ['rato', 'grita']
# ['hermano', 'persona', 'gritona']
# ['hermano', 'grita']
# ['grita']
# ['hermano', 'grita']
# ['entendi']
# ['enojon']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['NS']
# ['bebes', 'lloran']
# ['hermano', 'grita']
# ['hermano', 'cabeza', 'redonda', 'grita']
# ['grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'bebe', 'chilla', 'grita']
# ['hermano', 'grita']
# ['hermano', 'salta', 'grita']
# ['grita']
# ['hermano', 'grita']
# ['hermanito', 'grita', 'suelta', 'pelota']
# ['hermanito', 'grita', 'pelotas', 'pelotas']
# ['grita']
# ['circular', 'comelona']
# ['hermano', 'grita']
# ['dormido']
# ['grita']
# ['hermana', 'pelota', 'risa']
# ['NS']
# ['hermanito', 'llora', 'grita']
# ['gritona']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'griton']
# ['llora', 'grita', 'necesita']
# ['divertido', 'grita']
# ['gritona']
# ['gordito', 'griton']
# ['grita']
# ['grita']
# []
# ['bebe', 'meten', 'ladrillo', 'boca', 'callarlo']
# ['grita']
# ['grita']
# ['guste', 'decirle']
# ['grita']
# ['NS']
# ['pelota', 'gritona', 'commo', 'hermano']
# ['grita']
# ['hermanito', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'rueda']
# ['hermanito', 'grita']
# ['griton', 'juega', 'pelota']
# ['jugueton', 'grita']
# ['hermano', 'grita']
# ['hermanito', 'satltara', 'saltara', 'sentido']
# ['hermano', 'gritar']
# ['juega', 'pelota', 'grita']
# ['hermano', 'grita']
# ['grita']
# ['pelotas']
# ['grita']
# ['rebota', 'suena', 'grito']
# ['hermanito', 'grita']
# ['pelota', 'gritos', 'bebes', 'lloran', 'gritan', 'eructan']
# ['hermano', 'grita', 'gusta', 'saltar']
# ['chilla']
# ['hermano', 'grita', 'alto']
# ['grita']
# ['refiere', 'hermanito', 'griton', 'grita']
# ['hermano', 'grita', 'llora']
# ['hermano', 'grita']
# ['encanta', 'gritar']
# ['griton']
# ['hermano', 'chillon', 'griton']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['grita']
# ['hermanito', 'grita', 'eleva', 'pelota']
# ['hermano', 'grita']
# ['hermanito', 'grita', 'redondo']
# ['hermano', 'pasa', 'gritando']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'llora']
# ['hermano', 'grita']
# ['llora', 'molesta']
# ['hermano', 'grita', 'fuerte', 'diario']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['seguramente', 'bebe', 'bebes', 'gritan', 'lloran']
# ['grita']
# ['hermano', 'grita']
# ['hermanito', 'griton', 'chillon', 'comelon', 'etc.']
# ['grita']
# ['hermano', 'travieso', 'grita']
# ['hermano', 'grita', 'pelotas']
# ['hermano', 'grita', 'llora']
# ['hermanita', 'grita']
# ['grita', 'grita']
# ['nino', 'llora', 'grita', 'caso']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'enojon']
# ['hermano', 'grita']
# ['escandalosa']
# ['pasa', 'gritando']
# ['grita']
# ['hermano', 'gritando']
# ['griton']
# ['llora', 'grita', 'berrinches']
# ['hermanito', 'nino']
# ['grita']
# ['hermano', 'griton']
# ['hermano', 'chico', 'razonar', 'resuelve', 'gritos']
# ['hermana', 'persona', 'gritos']
# ['hermana', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['llora', 'grita']
# ['pelota', 'gritos', 'namas', 'pelota', 'jugar']
# ['hermanito', 'triste']
# ['hermano', 'pequeno', 'grita', 'muchisimo']
# ['hermanito', 'grita']
# ['hermano', 'grita']
# ['hermano', 'deja', 'gritar']
# ['llora', 'grita']
# ['hermanito', 'bebe', 'grita']
# ['hermano', 'grita']
# ['pelota']
# ['hermano', 'grita']
# ['hermano', 'pasa', 'gritando']
# ['ninos', 'chicos', 'gritan']
# ['latoso']
# ['gritar']
# ['hermanito', 'grita']
# ['bebe', 'tambiengrita', 'grita']
# ['hermano', 'griton']
# []
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['grita']
# ['NS']
# ['das', 'empieza', 'llorar', 'gritar']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'nino', 'griton']
# ['grita']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['pelota', 'gritos']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['pelota', 'gritos']
# ['hermano', 'griton']
# []
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermanito', 'pelota', 'gritos']
# ['hermano', 'griton']
# ['hermano', 'griton']
# ['hermanito', 'chiquito', 'bebe', 'llora', 'comida', 'leche', 'cambien', 'panal']
# ['hermano', 'grita']
# ['ninos', 'pequenos', 'gritan']
# ['grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'gordito', 'pelota', 'hermano', 'grita']
# ['hermanito', 'grita']
# ['hermanito', 'grita']
# ['grita']
# ['hermanito', 'pelota', 'grita']
# ['grita', 'agrega', 'pelota']
# ['hermano', 'grita']
# ['grita']
# ['hermano', 'llora']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['qu', 'hermano', 'grita']
# ['hermano', 'grita']
# ['grita']
# ['grita']
# ['hermano', 'grita']
# ['hermano', 'llora']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['NS']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'pelota', 'gritos']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermanito', 'pelota', 'gritos']
# ['presion']
# ['pelota', 'gritos']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermana', 'pelota', 'gritos']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'pelota', 'grita']
# ['grita']
# ['grita', 'rato']
# ['grita']
# ['hermano', 'grita']
# ['hermano', 'grita', 'llora']
# ['qu', 'hermano', 'grita']
# ['fer', 'rovin']
# ['grita']
# ['gritona']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['grita']
# ['hermano', 'pelota', 'grita', 'ayuden']
# ['grita']
# ['nino', 'gritando']
# ['gordito', 'grita']
# ['hermanito', 'grita']
# ['hermano', 'grita']
# ['grita', 'hermanitp', 'pelota']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['gordito', 'grita']
# ['grita']
# ['hermano', 'grita']
# ['grita']
# ['grita', 'feliz']
# ['gusta', 'jugar', 'futbol', 'pelota', 'suena']
# ['hermano', 'grita']
# ['grita', 'juega', 'grita']
# ['griton', 'latoso']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermanito', 'grita', 'pelota', 'gritos']
# ['grita', 'pelota', 'rebotar', 'suena']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['grita']
# ['chilla']
# ['grita']
# ['hermanito', 'griton']
# ['gritando']
# ['granos']
# ['hermano', 'grita']
# ['grita', 'travieso']
# ['berrinche', 'emocion']
# ['hermano', 'grita', 'simplemente', 'llora']
# ['hermano', 'gordito', 'grita']
# ['pelota', 'brinca', 'grita']
# ['gusta', 'rebote', 'pelota']
# ['hermano', 'grita']
# ['llora', 'pequeno']
# ['hermanito', 'grita']
# ['reganan', 'hemanos']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['grita']
# ['hermano', 'griton']
# ['hermanito', 'guardado', 'gritos']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'griton']
# ['hermano', 'escandaloso']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['puedes', 'hermanito', 'gordito', 'grita']
# ['hermano', 'rato', 'grita']
# ['grita', 'llora']
# ['hermano', 'grita', 'constantemente']
# ['hermano', 'menor', 'grita']
# ['hermano', 'grita']
# ['hermanito', 'grita', 'casa']
# ['hermano', 'grita']
# ['hermano', 'griton']
# ['gritar']
# ['grita', 'parar', 'pelota']
# ['ninos', 'chiquitos', 'berrinche']
# ['hermano', 'griton']
# ['hermanito', 'grita']
# ['hermanito', 'griton']
# ['grita']
# ['hermanito', 'berrinches']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'brinca', 'llora', 'gritos']
# ['grita']
# ['pelota', 'ruido', 'pelota', 'gritos']
# ['hermanito', 'gordo', 'gritos']
# ['hermano', 'gritando', 'saltando']
# ['hermano', 'grita']
# ['hermanito', 'grita', 'casa']
# ['hermano', 'gustan', 'gritos']
# ['hermano', 'grita']
# ['hermano', 'ruidoso']
# ['persona', 'gritar']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'griton']
# ['hermanito', 'llora', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita', 'pelota', 'entiendo']
# ['hermano', 'grita']
# ['hermano', 'gritando', 'pelota', 'rebota']
# ['hermanito', 'latoso']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['llorar', 'quejarse', 'llorar', 'rato', 'gritando']
# ['ruido']
# ['hermano', 'grita', 'normal']
# ['persona', 'gritona']
# ['nino', 'grita']
# ['griton']
# ['grita']
# ['hermano', 'griton']
# ['hermanito', 'sube', 'voz']
# ['refiere', 'hermano', 'grita', 'poeta', 've', 'mundo', 'pelotas']
# ['talves', 'hermano', 'grita']
# ['grita']
# ['silencio', 'jajajajaja']
# ['hermano', 'gritar', 'pelota', 'pelos']
# ['pequeno', 'lata']
# ['yoron']
# ['hermano', 'compran', 'pone', 'gritar']
# ['hermano', 'pelota', 'grita']
# ['grita']
# ['abla', 'grita']
# ['nina', 'pasa', 'llorando', 'asiendo', 'berrinche']
# ['grita']
# ['grita']
# ['hermano', 'grita']
# ['grita']
# ['voz', 'baja']
# ['grita']
# ['hermanito', 'grita']
# ['gordito', 'grita']
# ['hermano', 'nino', 'pequeno']
# ['gritos']
# ['exagera', 'berrinche']
# ['nolo', 'xd']
# ['llora']
# ['grita']
# ['dibertido']
# ['tocan', 'grito']
# ['hermanito', 'energias', 'gritar']
# ['hermanito', 'gritar']
# ['hermano', 'grita']
# ['hermano', 'alguien', 'grita']
# ['pegan', 'pone', 'gritar']
# ['pasa', 'gritando', 'pensativo', 'ajajjajaj']
# ['grita']
# ['hermano', 'etsa', 'gordo', 'pasa', 'gritando']
# ['frita']
# ['enpieza', 'gritar']
# ['chilla']
# []
# ['hermano', 'redondo', 'grita']
# ['hermanos', 'lloran']
# []
# ['qu', 'hermano', 'pasa', 'gritando', 'osea', 'desastroso']
# ['explica', 'hermano', 'grita', 'inquieto']
# ['13fg']
# ['griton']
# ['hermanito', 'gordo', 'grita']
# ['refiere', 'hermanito', 'grita']
# ['hermano', 'grita']
# ['hermano', 'chico', 'grita']
# ['grita', 'llora', 'pelota', 'gritos']
# ['hermano', 'quejar', 'rato', 'anda', 'gritando']
# ['nino', 'grita']
# ['grita']
# ['hermano', 'gritar', 'pelotas', 'pelos']
# ['grita']
# ['lloron']
# ['sentimientos']
# ['grita']
# ['hermano', 'grita', 'desespera', 'frase', 'pelota', 'gritos', 'supongo']
# ['grita']
# ['hermanitos', 'molestones']
# ['hermano', 'pasa', 'gritando', 'molesta']
# ['hermano', 'grita']
# ['grita']
# ['griton']
# ['grita']
# ['gordo', 'gita']
# ['ruidoso']
# ['lata']
# ['hermanito', 'grita']
# ['gryta', 'ermanito']
# ['hermanito', 'grita']
# ['hermano', 'grita']
# ['fastidioso']
# ['pelota', 'mu', 'enojada']
# ['see']
# ['platicon']
# ['berrinchudo']
# ['hermanito', 'nino', 'gritos']
# ['xk', 'hermano', 'simpre', 'grita']
# ['hermano', 'gordo', 'grita']
# ['hermano', 'griton']
# ['alguien', 'griton']
# ['hermano', 'inquieto']
# ['ninos', 'escandalosos']
# ['forma', 'expresar', 'palabras', 'metaforicas']
# ['hermano', 'persona', 'grita']
# ['grita', 'salta']
# ['griton', 'molesto']
# ['significa', 'reclama', 'llora']
# ['hermanito', 'grite']
# ['unde', 'llanto']
# ['hermano', 'grita']
# ['hermanito', 'grita']
# ['poequ', 'griton']
# ['grita']
# ['grita']
# ['llora']
# ['nino', 'pasa', 'gritando', 'llorando']
# ['chillan', 'gritan', 'exageran']
# ['mama', 'persona', 'gritona']
# ['entisende']
# ['pasa', 'gritando']
# ['grita']
# ['hermano', 'nino', 'grita']
# ['ruidoso']
# ['maquina', 'alguien', 'grita']
# ['pirhhhhgvfriufueiituj']
# ['llora']
# ['puen', 'hermana', 'grita']
# ['NS']
# ['and', 'fort']
# ['grita']
# ['grita']
# ['hermano', 'grita']
# ['grita']
# ['hermanito', 'gritando', 'ruido']
# ['hermano', 'persona', 'ruidosa']
# ['grita']
# ['gritando', 'parar']
# ['hermanito', 'griton', 'hermanita', 'loco']
# ['grita']
# ['hermano', 'grita']
# ['grita']
# ['hermano', 'energia']
# ['pequeno', 'grita']
# ['pequeno', 'grita']
# ['gritona']
# ['gritar']
# ['grita']
# ['hermano', 'grita']
# ['parecer', 'hermano', 'grita', 'entiende', 'metafora', 'pelota']
# ['hermano', 'grita']
# ['refiere', 'persona', 'grita']
# ['hermano', 'escandalo']
# ['hecha', 'relajo']
# ['loco']
# ['grita']
# ['hermano', 'imperactivo']
# ['hermano', 'pasa', 'gritando']
# ['escandalo']
# ['alborotado']
# ['pasa', 'gritando']
# ['gordito', 'grita']
# ['grita']
# ['hermanito', 'gordito', 'griton']
# ['grita']
# ['hermano', 'gritando']
# ['gritar']
# ['hermano', 'grita', 'sale', 'circulo']
# ['humano', 'gordo', 'chillar']
# ['grita']
# ['grita']
# ['hermano', 'pasa', 'gritando']
# ['grita', 'lata']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['grita', 'hablar', 'grita']
# ['nino', 'nino', 'grita']
# ['hermano', 'grita', 'pelota', 'botando']
# ['alguien', 'grita']
# ['grita']
# ['hermano', 'quejumbroso', 'lloron']
# ['pasa', 'gritando']
# ['sobrepeso']
# ['hablando', 'grtando']
# ['nino', 'gordo', 'grita', 'tono', 'voz', 'fuertealto']
# ['grita']
# []
# ['grita']
# ['hermano', 'gritando', 'conjunto', 'gritos']
# ['grita']
# ['grita']
# ['hermano', 'grita']
# ['hermano', 'griton']
# ['hermano', 'grita', 'ruido']
# ['grita']
# ['grita']
# ['grita']
# ['gritando']
# ['mueve', 'pelota', 'ruidoso']
# ['hermano', 'chiquito', 'grita']
# ['hermano', 'grita']
# ['NS']
# ['significa', 'nino', 'chillon', 'normalmente', 'desespera', 'grita']
# ['hermano', 'grita', 'gordo']
# ['hermano', 'griton']
# ['grita']
# ['hermano', 'nino', 'grita']
# ['grita', 'exceso']
# ['hermano', 'alguien', 'gritar', 'hablar']
# ['hermanito', 'griton', 'llora', 'llorona']
# ['alguien', 'grita']
# ['hermano', 'grita']
# ['hermano', 'representa', 'infante', 'plena', 'etapa', 'inocencia', 'escandalo']
# ['hermano', 'grita']
# ['grita']
# ['deja', 'gritar']
# ['escandalo', 'quedar', 'quieto']
# ['grita']
# ['irritanto']
# ['hermano', 'gordito', 'redondo', 'constantemente', 'gritando']
# ['machina', 'gritar']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['deja', 'hablar']
# ['nino', 'gordito', 'pasa', 'gritando']
# ['ninos', 'demasiados', 'inquietos', 'ruidosos']
# ['hermanito', 'grita']
# ['hermando', 'nino', 'travieso']
# ['hermano', 'grita']
# ['hermanito', 'griton']
# ['llorando', 'gritando']
# ['dolor', 'cabeza']
# ['invalida', 'sistema']
# ['grita']
# ['berrinche', 'grita']
# ['nino', 'inquieto']
# ['hermanito', 'grita']
# ['hermano', 'encanta', 'cantar']
# ['grita']
# ['ternura']
# ['gordito', 'griton']
# ['ruidosos']
# ['grita']
# ['hermano', 'grita']
# ['hermanito', 'ruidoso']
# ['hermanito', 'estresa', 'bes', 'grita']
# ['hermanito', 'grita']
# ['nino', 'ruidoso']
# ['ermano', 'grita']
# ['hermano', 'grita', 'llora', 'autor@', 'refiere', 'sentido', 'literario']
# ['grita']
# ['ninos', 'pequenos', 'regular', 'gritan']
# ['chillon']
# ['bb']
# ['grita']
# ['hermanito', 'grita']
# ['hermano', 'representa', 'pelota', 'grita']
# ['grita', 'fuerte']
# ['llora', 'grita']
# ['pelota']
# ['hermano', 'persona', 'grita']
# ['nino']
# ['grita']
# ['hermanito', 'grita']
# ['hermano', 'grita']
# ['inquieto']
# ['asu', 'hermano', 'gustan', 'grillos', 'alv']
# ['grita']
# ['hermono', 'grita']
# ['gordo', 'gusta', 'cantar']
# ['hermano', 'grita']
# ['grita']
# ['hermano', 'grita', 'grita', 'parar', 'sentido']
# ['ninos', 'energeticos', 'tienden', 'gritar']
# ['osea', 'hermano', 'grita']
# ['hermano', 'llorando', 'gritando']
# ['ruido']
# ['bote', 'grito', 'hermano']
# ['hermano', 'pasa', 'gritando']
# ['mete', 'goles']
# ['hermanito', 'grita']
# ['hermano', 'pasa', 'gritando']
# ['grito']
# ['hermano', 'latoso']
# ['llega', 'gritar']
# ['gritos']
# ['hermano', 'grita', 'ase', 'esallar', 'alas', 'personas']
# ['fastidioso']
# ['grita']
# ['grande', 'grita']
# ['grita']
# ['pasa', 'gritando']
# ['hermana', 'grita']
# ['hermanito', 'griton']
# ['grita']
# ['refiere', 'hermano', 'persona', 'gritona']
# ['ninos', 'gritan']
# ['toso']
# ['gritano']
# ['hermano', 'bebe', 'grita', 'llora']
# ['gritando', 'hermano']
# ['hermanito', 'grita']
# ['hermanito', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita', 'metafora']
# ['entiendo', 'hermano', 'grita', 'refiere']
# ['refiere', 'hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'lloron', 'enojon', 'grita']
# ['qwee']
# ['regana', 'hermano', 'menor']
# ['persona', 'grita']
# ['alguien', 'pelota', 'mayoria', 'tratan', 'decirle', 'gordoa', 'supongo', 'hermano', 'gordo', 'griton']
# ['persona', 'inquieta']
# ['grita']
# ['mueve', 'ruido']
# ['cosa', 'altera', 'grita']
# ['quieta']
# ['hermanito', 'grita', 'casa']
# ['ami', 'entender', 'persona', 'referencia', 'pelota', 'hermano', 'inquieto']
# ['hermano', 'gusta', 'gritar', 'hablar', 'fuerte']
# ['fastidioso']
# ['grita']
# ['entiendo', 'nino', 'pelota', 'super', 'fantastica']
# ['ninos', 'gritan', 'pequenos']
# ['hermano', 'bola', 'pelos']
# ['lida', 'conmigom', 'parese', 'tierno', 'pelota', 'pelos', 'sister']
# ['hermanito', 'grita', 'imperactivo']
# ['hermano', 'grita']
# ['grita']
# ['nino', 'griton', 'juega', 'pelota']
# ['grita']
# ['nino', 'grita', 'expresa', 'comun', 'forma']
# ['hermano', 'griton']
# ['ththt']
# ['grita']
# ['moleta']
# ['apodo']
# ['hermano', 'grillos']
# ['grita', 'piensa', 'pelota']
# ['latoso']
# ['gordito', 'pasa', 'gritando']
# ['pasa', 'gritando']
# ['peota', 'quieren', 'grita']
# ['supongo', 'nino', 'grita', 'nino', 'anos']
# ['sobrina']
# ['hermanito', 'griton']
# ['hermano', 'grita']
# ['grita', 'hermano']
# ['hermanito', 'grita']
# ['refiere', 'hermana']
# ['hermano', 'grita', 'muho', 'bota', 'pelota']
# ['grita']
# ['pasa', 'gritando']
# ['hermano', 'grita', 'ruidoso']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'griton', 'escandaloso', 'travieso']
# ['hermano', 'gritando']
# ['hermano', 'nino', 'super', 'griton']
# ['hermanos', 'molestar', 'normalmente', 'peleas']
# ['hermano', 'grita', 'vuelve', 'constante']
# ['nino', 'llamar', 'atencion', 'gritos']
# ['hermano', 'grita']
# ['molesto', 'castroso']
# ['hermanito', 'grita']
# ['nino', 'gordito', 'pelota', 'grita']
# ['referencia', 'hermano', 'grita', 'hubieran', 'puesto', 'tipo', 'sobrante', 'pelota']
# ['griton']
# ['altera', 'rapido']
# ['grita']
# ['hermanito', 'nino', 'grita']
# ['hermano', 'grita']
# ['grita']
# ['deja', 'gritar']
# ['simplemente', 'hermano', 'persona', 'gritona', 'pelota', 'refiere', 'cabeza']
# ['gordo', 'gusta', 'gritar']
# ['hermano', 'grita']
# ['ninos', 'ruido']
# ['ruidoso']
# ['qiere']
# ['grita', 'rato']
# ['grita']
# ['gritando']
# ['hermano', 'pasa', 'gritando']
# ['persona', 'reganona', 'grita']
# ['latoso']
# ['hermano', 'grita']
# ['hermanito', 'griton', 'forma', 'pelota']
# ['gritando']
# ['hermano', 'expresivo']
# ['llora']
# ['grita']
# ['anda', 'brincando', 'gritando']
# ['hermano', 'grita']
# ['nino', 'grita']
# ['hermanito', 'grita']
# ['persona', 'gordita', 'grita']
# ['refiere', 'hermano', 'inquieto']
# ['nino', 'griton']
# ['persona', 'grita']
# ['hermanito', 'pequeno', 'deja', 'llorar', 'gritar', 'pasa']
# ['gritar', 'molestar']
# ['hermano', 'grita']
# ['persona', 'gorda', 'grita']
# ['grita', 'rebota']
# ['grita']
# ['cosa', 'llora', 'grita']
# ['pasa', 'gritando']
# ['talvez', 'sienpre', 'corriendo', 'em', 'paz']
# ['chiquito', 'grita']
# ['hermano', 'gritar', 'escandaloso']
# ['nino', 'griton']
# ['nino', 'griton']
# ['hermano', 'grita', 'pelota', 'ocupando', 'alternativa']
# ['hermano', 'escandaloso']
# ['rato', 'gritando']
# ['grita']
# ['calla']
# ['hermano', 'grita']
# ['grita']
# ['hermano', 'grita']
# ['lleno', 'gritos']
# ['llora', 'grita']
# ['describe', 'hermano', 'grita']
# ['grita']
# ['grita']
# ['hermano', 'menor', 'grita']
# ['lleno', 'gritos', 'listos', 'salir']
# ['molestando']
# ['escandaloso', 'ruidoso']
# ['hermano', 'griton', 'unico']
# ['significa', 'persona', 'grita']
# ['significa', 'hermano', 'escandaloso']
# ['refiere', 'hermano', 'grita']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['pequeno', 'llora', 'grita']
# ['grita', 'probablemente', 'menor']
# ['hermano', 'griton']
# ['nino', 'gordo', 'ruido']
# ['gritando']
# ['pq', 'espanta', 'facil', 'salta', 'tiemmpo', 'gfrita']
# ['grita', 'fuerte', 'grita']
# ['hermano', 'tiende', 'gritar']
# ['refieren', 'pelota', 'representa', 'hermano', 'hermano', 'grita', 'accion', 'representa', 'hermano']
# ['hermano', 'nino', 'pequeno', 'ninos', 'pequenos', 'gritan', 'berrinches', 'bebe', 'hermano', 'bebes', 'lloran']
# ['gordo', 'grita']
# ['pelota', 'significa', 'impratividad', 'osea', 'rebotar', 'gritos', 'representa', 'ruido']
# ['hermano', 'deja', 'gritar']
# ['gritan']
# ['grita', 'demaciado']
# ['nino', 'grita', 'continuo']
# ['significa', 'hermano', 'llora', 'gritos']
# ['hermano', 'griton']
# ['grita', 'llora', 'grita']
# ['hermano', 'desastroso', 'grita']
# ['hermano', 'autor', 'alguien', 'expresa', 'demandante']
# ['hermano', 'grita', 'pelota(salta', 'bota']
# ['escandaloso']
# ['hermano', 'grita']
# ['molesta', 'facilmente']
# ['hermano', 'grita']
# ['hermano', 'grita']
# ['pega', 'gritos']
# ['persona', 'grita']
# ['hermano', 'grita']
# ['alguien', 'gritar']
# ['hermanos', 'gritan', 'lloran', 'menores', 'casas', 'comparo', 'pelota']
# ['that', 'maybe', 'her', 'sister', 'always', 'screams', 'to', 'her']
# ['bebe', 'grita']
# ['gritando']
# ['deja', 'gritar']
# ['hermanito', 'grita']
# ['significar', 'hermano', 'ruidoso']
# ['grita']
# ['usando', 'palabra', 'pelota', 'ue', 'pensar', 'hermanito', 'simplemente', 'griton']
# ['nino', 'grita']
# ['canta',
#  'hermano grita',
#  'NS',
#  'hermano llora',
#  'travieso llora',
#  'hemanos gritan',
#  'hermano grita',
#  'gritamos',
#  'irritante llora',
#  'hermano grita',
#  'hermano griton',
#  'hermano grita',
#  'NS',
#  'hermano grita',
#  'grita reir',
#  'hermano chillon',
#  'grita',
#  'grita',
#  'lenguaje literal',
#  'hermano gritando',
#  'griton',
#  'hermano pelota grita',
#  'enoja empieza gritar',
#  'hermano grita',
#  'hermano grita',
#  '',
#  'grita fuerte',
#  'grita',
#  'grita hermano',
#  'asusta enojona grita furia',
#  'lloron pelota gritos',
#  'hermano grita',
#  'hermano grita',
#  'bota',
#  'hermano gritando',
#  'grita',
#  'aburrido',
#  'hermano mayoria grita llora',
#  'hermanito pequeno grita',
#  'hermanito grita',
#  'grita',
#  'chilla',
#  'gritando',
#  'hermanas enojan',
#  'hermano travieso',
#  'grita',
#  'hermano griton',
#  'escandaloso',
#  'llora',
#  'hermano grita',
#  'pelota inflada',
#  'grita',
#  'persona grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'nino griton',
#  'hermanito grita',
#  'griton',
#  'hermano grita',
#  'hermano griton',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'gordito grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano griton',
#  'expresa llora',
#  'gordo grita',
#  'hermano grita',
#  'grita',
#  'rato grita',
#  'hermano persona gritona',
#  'hermano grita',
#  'grita',
#  'hermano grita',
#  'entendi',
#  'enojon',
#  'hermano grita',
#  'hermano grita',
#  'NS',
#  'bebes lloran',
#  'hermano grita',
#  'hermano cabeza redonda grita',
#  'grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano bebe chilla grita',
#  'hermano grita',
#  'hermano salta grita',
#  'grita',
#  'hermano grita',
#  'hermanito grita suelta pelota',
#  'hermanito grita pelotas pelotas',
#  'grita',
#  'circular comelona',
#  'hermano grita',
#  'dormido',
#  'grita',
#  'hermana pelota risa',
#  'NS',
#  'hermanito llora grita',
#  'gritona',
#  'hermano grita',
#  'hermano grita',
#  'hermano griton',
#  'llora grita necesita',
#  'divertido grita',
#  'gritona',
#  'gordito griton',
#  'grita',
#  'grita',
#  '',
#  'bebe meten ladrillo boca callarlo',
#  'grita',
#  'grita',
#  'guste decirle',
#  'grita',
#  'NS',
#  'pelota gritona commo hermano',
#  'grita',
#  'hermanito grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano rueda',
#  'hermanito grita',
#  'griton juega pelota',
#  'jugueton grita',
#  'hermano grita',
#  'hermanito satltara saltara sentido',
#  'hermano gritar',
#  'juega pelota grita',
#  'hermano grita',
#  'grita',
#  'pelotas',
#  'grita',
#  'rebota suena grito',
#  'hermanito grita',
#  'pelota gritos bebes lloran gritan eructan',
#  'hermano grita gusta saltar',
#  'chilla',
#  'hermano grita alto',
#  'grita',
#  'refiere hermanito griton grita',
#  'hermano grita llora',
#  'hermano grita',
#  'encanta gritar',
#  'griton',
#  'hermano chillon griton',
#  'hermano grita',
#  'hermano grita',
#  'grita',
#  'hermanito grita eleva pelota',
#  'hermano grita',
#  'hermanito grita redondo',
#  'hermano pasa gritando',
#  'hermano grita',
#  'hermano grita',
#  'hermano llora',
#  'hermano grita',
#  'llora molesta',
#  'hermano grita fuerte diario',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'seguramente bebe bebes gritan lloran',
#  'grita',
#  'hermano grita',
#  'hermanito griton chillon comelon etc.',
#  'grita',
#  'hermano travieso grita',
#  'hermano grita pelotas',
#  'hermano grita llora',
#  'hermanita grita',
#  'grita grita',
#  'nino llora grita caso',
#  'hermano grita',
#  'hermano grita',
#  'hermano enojon',
#  'hermano grita',
#  'escandalosa',
#  'pasa gritando',
#  'grita',
#  'hermano gritando',
#  'griton',
#  'llora grita berrinches',
#  'hermanito nino',
#  'grita',
#  'hermano griton',
#  'hermano chico razonar resuelve gritos',
#  'hermana persona gritos',
#  'hermana grita',
#  'hermano grita',
#  'hermano grita',
#  'llora grita',
#  'pelota gritos namas pelota jugar',
#  'hermanito triste',
#  'hermano pequeno grita muchisimo',
#  'hermanito grita',
#  'hermano grita',
#  'hermano deja gritar',
#  'llora grita',
#  'hermanito bebe grita',
#  'hermano grita',
#  'pelota',
#  'hermano grita',
#  'hermano pasa gritando',
#  'ninos chicos gritan',
#  'latoso',
#  'gritar',
#  'hermanito grita',
#  'bebe tambiengrita grita',
#  'hermano griton',
#  '',
#  'hermano griton',
#  'hermano griton',
#  'grita',
#  'NS',
#  'das empieza llorar gritar',
#  'hermano griton',
#  'hermano griton',
#  'hermano nino griton',
#  'grita',
#  'hermano griton',
#  'hermano griton',
#  'hermano griton',
#  'pelota gritos',
#  'hermano griton',
#  'hermano griton',
#  'pelota gritos',
#  'hermano griton',
#  '',
#  'hermano griton',
#  'hermano griton',
#  'hermano griton',
#  'hermano griton',
#  'hermano griton',
#  'hermano griton',
#  'hermano griton',
#  'hermano griton',
#  'hermano griton',
#  'hermano griton',
#  'hermano griton',
#  'hermano griton',
#  'hermano griton',
#  'hermano griton',
#  'hermanito pelota gritos',
#  'hermano griton',
#  'hermano griton',
#  'hermanito chiquito bebe llora comida leche cambien panal',
#  'hermano grita',
#  'ninos pequenos gritan',
#  'grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano gordito pelota hermano grita',
#  'hermanito grita',
#  'hermanito grita',
#  'grita',
#  'hermanito pelota grita',
#  'grita agrega pelota',
#  'hermano grita',
#  'grita',
#  'hermano llora',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'qu hermano grita',
#  'hermano grita',
#  'grita',
#  'grita',
#  'hermano grita',
#  'hermano llora',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'NS',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermano pelota gritos',
#  'hermano grita',
#  'hermano grita',
#  'hermanito pelota gritos',
#  'presion',
#  'pelota gritos',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermana pelota gritos',
#  'hermano grita',
#  'hermano grita',
#  'hermano pelota grita',
#  'grita',
#  'grita rato',
#  'grita',
#  'hermano grita',
#  'hermano grita llora',
#  'qu hermano grita',
#  'fer rovin',
#  'grita',
#  'gritona',
#  'hermano grita',
#  'hermano grita',
#  'grita',
#  'hermano pelota grita ayuden',
#  'grita',
#  'nino gritando',
#  'gordito grita',
#  'hermanito grita',
#  'hermano grita',
#  'grita hermanitp pelota',
#  'hermano grita',
#  'hermano grita',
#  'gordito grita',
#  'grita',
#  'hermano grita',
#  'grita',
#  'grita feliz',
#  'gusta jugar futbol pelota suena',
#  'hermano grita',
#  'grita juega grita',
#  'griton latoso',
#  'hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'hermanito grita pelota gritos',
#  'grita pelota rebotar suena',
#  'hermano grita',
#  'hermano grita',
#  'grita',
#  'chilla',
#  'grita',
#  'hermanito griton',
#  'gritando',
#  'granos',
#  'hermano grita',
#  'grita travieso',
#  'berrinche emocion',
#  'hermano grita simplemente llora',
#  'hermano gordito grita',
#  'pelota brinca grita',
#  'gusta rebote pelota',
#  'hermano grita',
#  'llora pequeno',
#  'hermanito grita',
#  'reganan hemanos',
#  'hermano grita',
#  'hermano grita',
#  'grita',
#  'hermano grita',
#  'hermano grita',
#  'grita',
#  'hermano griton',
#  'hermanito guardado gritos',
#  'hermano grita',
#  'hermano grita',
#  'hermano griton',
#  'hermano escandaloso',
#  'hermano grita',
#  'hermano grita',
#  'puedes hermanito gordito grita',
#  'hermano rato grita',
#  'grita llora',
#  'hermano grita constantemente',
#  'hermano menor grita',
#  'hermano grita',
#  'hermanito grita casa',
#  'hermano grita',
#  'hermano griton',
#  'gritar',
#  'grita parar pelota',
#  'ninos chiquitos berrinche',
#  'hermano griton',
#  'hermanito grita',
#  'hermanito griton',
#  'grita',
#  'hermanito berrinches',
#  'hermano grita',
#  'hermano grita',
#  'hermano brinca llora gritos',
#  'grita',
#  'pelota ruido pelota gritos',
#  'hermanito gordo gritos',
#  'hermano gritando saltando',
#  'hermano grita',
#  'hermanito grita casa',
#  'hermano gustan gritos',
#  'hermano grita',
#  'hermano ruidoso',
#  'persona gritar',
#  'hermano grita',
#  'hermano grita',
#  'hermano griton',
#  'hermanito llora grita',
#  'hermano grita',
#  'hermano grita pelota entiendo',
#  'hermano grita',
#  'hermano gritando pelota rebota',
#  'hermanito latoso',
#  'hermano grita',
#  'hermano grita',
#  'llorar quejarse llorar rato gritando',
#  'ruido',
#  'hermano grita normal',
#  'persona gritona',
#  'nino grita',
#  'griton',
#  'grita',
#  'hermano griton',
#  'hermanito sube voz',
#  'refiere hermano grita poeta ve mundo pelotas',
#  'talves hermano grita',
#  'grita',
#  'silencio jajajajaja',
#  'hermano gritar pelota pelos',
#  'pequeno lata',
#  'yoron',
#  'hermano compran pone gritar',
#  'hermano pelota grita',
#  'grita',
#  'abla grita',
#  'nina pasa llorando asiendo berrinche',
#  'grita',
#  'grita',
#  'hermano grita',
#  'grita',
#  'voz baja',
#  'grita',
#  'hermanito grita',
#  'gordito grita',
#  'hermano nino pequeno',
#  'gritos',
#  'exagera berrinche',
#  'nolo xd',
#  'llora',
#  'grita',
#  'dibertido',
#  'tocan grito',
#  'hermanito energias gritar',
#  'hermanito gritar',
#  'hermano grita',
#  'hermano alguien grita',
#  'pegan pone gritar',
#  'pasa gritando pensativo ajajjajaj',
#  'grita',
#  'hermano etsa gordo pasa gritando',
#  'frita',
#  'enpieza gritar',
#  'chilla',
#  '',
#  'hermano redondo grita',
#  'hermanos lloran',
#  '',
#  'qu hermano pasa gritando osea desastroso',
#  'explica hermano grita inquieto',
#  '13fg',
#  'griton',
#  'hermanito gordo grita',
#  'refiere hermanito grita',
#  'hermano grita',
#  'hermano chico grita',
#  'grita llora pelota gritos',
#  'hermano quejar rato anda gritando',
#  'nino grita',
#  'grita',
#  'hermano gritar pelotas pelos',
#  'grita',
#  'lloron',
#  'sentimientos',
#  'grita',
#  'hermano grita desespera frase pelota gritos supongo',
#  'grita',
#  'hermanitos molestones',
#  'hermano pasa gritando molesta',
#  'hermano grita',
#  'grita',
#  'griton',
#  'grita',
#  'gordo gita',
#  'ruidoso',
#  'lata',
#  'hermanito grita',
#  'gryta ermanito',
#  'hermanito grita',
#  'hermano grita',
#  'fastidioso',
#  'pelota mu enojada',
#  'see',
#  'platicon',
#  'berrinchudo',
#  'hermanito nino gritos',
#  'xk hermano simpre grita',
#  'hermano gordo grita',
#  'hermano griton',
#  'alguien griton',
#  'hermano inquieto',
#  'ninos escandalosos',
#  'forma expresar palabras metaforicas',
#  'hermano persona grita',
#  'grita salta',
#  'griton molesto',
#  'significa reclama llora',
#  'hermanito grite',
#  'unde llanto',
#  'hermano grita',
#  'hermanito grita',
#  'poequ griton',
#  'grita',
#  'grita',
#  'llora',
#  'nino pasa gritando llorando',
#  'chillan gritan exageran',
#  'mama persona gritona',
#  'entisende',
#  'pasa gritando',
#  'grita',
#  'hermano nino grita',
#  'ruidoso',
#  'maquina alguien grita',
#  'pirhhhhgvfriufueiituj',
#  'llora',
#  'puen hermana grita',
#  'NS',
#  'and fort',
#  'grita',
#  'grita',
#  'hermano grita',
#  'grita',
#  'hermanito gritando ruido',
#  'hermano persona ruidosa',
#  'grita',
#  'gritando parar',
#  'hermanito griton hermanita loco',
#  'grita',
#  'hermano grita',
#  'grita',
#  'hermano energia',
#  'pequeno grita',
#  'pequeno grita',
#  'gritona',
#  'gritar',
#  'grita',
#  'hermano grita',
#  'parecer hermano grita entiende metafora pelota',
#  'hermano grita',
#  'refiere persona grita',
#  'hermano escandalo',
#  'hecha relajo',
#  'loco',
#  'grita',
#  'hermano imperactivo',
#  'hermano pasa gritando',
#  'escandalo',
#  'alborotado',
#  'pasa gritando',
#  'gordito grita',
#  'grita',
#  'hermanito gordito griton',
#  'grita',
#  'hermano gritando',
#  'gritar',
#  'hermano grita sale circulo',
#  'humano gordo chillar',
#  'grita',
#  'grita',
#  'hermano pasa gritando',
#  'grita lata',
#  'hermano grita',
#  'hermano grita',
#  'grita hablar grita',
#  'nino nino grita',
#  'hermano grita pelota botando',
#  'alguien grita',
#  'grita',
#  'hermano quejumbroso lloron',
#  'pasa gritando',
#  'sobrepeso',
#  'hablando grtando',
#  'nino gordo grita tono voz fuertealto',
#  'grita',
#  '',
#  'grita',
#  'hermano gritando conjunto gritos',
#  'grita',
#  'grita',
#  'hermano grita',
#  'hermano griton',
#  'hermano grita ruido',
#  'grita',
#  'grita',
#  'grita',
#  'gritando',
#  'mueve pelota ruidoso',
#  'hermano chiquito grita',
#  'hermano grita',
#  'NS',
#  'significa nino chillon normalmente desespera grita',
#  'hermano grita gordo',
#  'hermano griton',
#  'grita',
#  'hermano nino grita',
#  'grita exceso',
#  'hermano alguien gritar hablar',
#  'hermanito griton llora llorona',
#  'alguien grita',
#  'hermano grita',
#  'hermano representa infante plena etapa inocencia escandalo',
#  'hermano grita',
#  'grita',
#  'deja gritar',
#  'escandalo quedar quieto',
#  'grita',
#  'irritanto',
#  'hermano gordito redondo constantemente gritando',
#  'machina gritar',
#  'hermano grita',
#  'hermano grita',
#  'deja hablar',
#  'nino gordito pasa gritando',
#  'ninos demasiados inquietos ruidosos',
#  'hermanito grita',
#  'hermando nino travieso',
#  'hermano grita',
#  'hermanito griton',
#  'llorando gritando',
#  'dolor cabeza',
#  'invalida sistema',
#  'grita',
#  'berrinche grita',
#  'nino inquieto',
#  'hermanito grita',
#  'hermano encanta cantar',
#  'grita',
#  'ternura',
#  'gordito griton',
#  'ruidosos',
#  'grita',
#  'hermano grita',
#  'hermanito ruidoso',
#  'hermanito estresa bes grita',
#  'hermanito grita',
#  'nino ruidoso',
#  'ermano grita',
#  'hermano grita llora autor@ refiere sentido literario',
#  'grita',
#  'ninos pequenos regular gritan',
#  'chillon',
#  'bb',
#  'grita',
#  'hermanito grita',
#  'hermano representa pelota grita',
#  'grita fuerte',
#  'llora grita',
#  'pelota',
#  'hermano persona grita',
#  'nino',
#  'grita',
#  'hermanito grita',
#  'hermano grita',
#  'inquieto',
#  'asu hermano gustan grillos alv',
#  'grita',
#  'hermono grita',
#  'gordo gusta cantar',
#  'hermano grita',
#  'grita',
#  'hermano grita grita parar sentido',
#  'ninos energeticos tienden gritar',
#  'osea hermano grita',
#  'hermano llorando gritando',
#  'ruido',
#  'bote grito hermano',
#  'hermano pasa gritando',
#  'mete goles',
#  'hermanito grita',
#  'hermano pasa gritando',
#  'grito',
#  'hermano latoso',
#  'llega gritar',
#  'gritos',
#  'hermano grita ase esallar alas personas',
#  'fastidioso',
#  'grita',
#  'grande grita',
#  'grita',
#  'pasa gritando',
#  'hermana grita',
#  'hermanito griton',
#  'grita',
#  'refiere hermano persona gritona',
#  'ninos gritan',
#  'toso',
#  'gritano',
#  'hermano bebe grita llora',
#  'gritando hermano',
#  'hermanito grita',
#  'hermanito grita',
#  'hermano grita',
#  'hermano grita metafora',
#  'entiendo hermano grita refiere',
#  'refiere hermano grita',
#  'hermano grita',
#  'hermano lloron enojon grita',
#  'qwee',
#  'regana hermano menor',
#  'persona grita',
#  'alguien pelota mayoria tratan decirle gordoa supongo hermano gordo griton',
#  'persona inquieta',
#  'grita',
#  'mueve ruido',
#  'cosa altera grita',
#  'quieta',
#  'hermanito grita casa',
#  'ami entender persona referencia pelota hermano inquieto',
#  'hermano gusta gritar hablar fuerte',
#  'fastidioso',
#  'grita',
#  'entiendo nino pelota super fantastica',
#  'ninos gritan pequenos',
#  'hermano bola pelos',
#  'lida conmigom parese tierno pelota pelos sister',
#  'hermanito grita imperactivo',
#  'hermano grita',
#  'grita',
#  'nino griton juega pelota',
#  'grita',
#  'nino grita expresa comun forma',
#  'hermano griton',
#  'ththt',
#  'grita',
#  'moleta',
#  'apodo',
#  'hermano grillos',
#  'grita piensa pelota',
#  'latoso',
#  'gordito pasa gritando',
#  'pasa gritando',
#  'peota quieren grita',
#  'supongo nino grita nino anos',
#  'sobrina',
#  'hermanito griton',
#  'hermano grita',
#  'grita hermano',
#  'hermanito grita',
#  'refiere hermana',
#  'hermano grita muho bota pelota',
#  'grita',
#  'pasa gritando',
#  'hermano grita ruidoso',
#  'hermano grita',
#  'hermano grita',
#  'hermano griton escandaloso travieso',
#  'hermano gritando',
#  'hermano nino super griton',
#  'hermanos molestar normalmente peleas',
#  'hermano grita vuelve constante',
#  'nino llamar atencion gritos',
#  'hermano grita',
#  'molesto castroso',
#  'hermanito grita',
#  'nino gordito pelota grita',
#  'referencia hermano grita hubieran puesto tipo sobrante pelota',
#  'griton',
#  'altera rapido',
#  'grita',
#  'hermanito nino grita',
#  'hermano grita',
#  'grita',
#  'deja gritar',
#  'simplemente hermano persona gritona pelota refiere cabeza',
#  'gordo gusta gritar',
#  'hermano grita',
#  'ninos ruido',
#  'ruidoso',
#  'qiere',
#  'grita rato',
#  'grita',
#  'gritando',
#  'hermano pasa gritando',
#  'persona reganona grita',
#  'latoso',
#  'hermano grita',
#  'hermanito griton forma pelota',
#  'gritando',
#  'hermano expresivo',
#  'llora',
#  'grita',
#  'anda brincando gritando',
#  'hermano grita',
#  'nino grita',
#  'hermanito grita',
#  'persona gordita grita',
#  'refiere hermano inquieto',
#  'nino griton',
#  'persona grita',
#  'hermanito pequeno deja llorar gritar pasa',
#  'gritar molestar',
#  'hermano grita',
#  'persona gorda grita',
#  'grita rebota',
#  'grita',
#  'cosa llora grita',
#  'pasa gritando',
#  'talvez sienpre corriendo em paz',
#  'chiquito grita',
#  'hermano gritar escandaloso',
#  'nino griton',
#  'nino griton',
#  'hermano grita pelota ocupando alternativa',
#  'hermano escandaloso',
#  'rato gritando',
#  'grita',
#  'calla',
#  'hermano grita',
#  'grita',
#  'hermano grita',
#  'lleno gritos',
#  'llora grita',
#  'describe hermano grita',
#  'grita',
#  'grita',
#  'hermano menor grita',
#  'lleno gritos listos salir',
#  'molestando',
#  'escandaloso ruidoso',
#  'hermano griton unico',
#  'significa persona grita',
#  'significa hermano escandaloso',
#  'refiere hermano grita',
#  'hermano grita',
#  'hermano grita',
#  'pequeno llora grita',
#  'grita probablemente menor',
#  'hermano griton',
#  'nino gordo ruido',
#  'gritando',
#  'pq espanta facil salta tiemmpo gfrita',
#  'grita fuerte grita',
#  'hermano tiende gritar',
#  'refieren pelota representa hermano hermano grita accion representa hermano',
#  'hermano nino pequeno ninos pequenos gritan berrinches bebe hermano bebes lloran',
#  'gordo grita',
#  'pelota significa impratividad osea rebotar gritos representa ruido',
#  'hermano deja gritar',
#  'gritan',
#  'grita demaciado',
#  'nino grita continuo',
#  'significa hermano llora gritos',
#  'hermano griton',
#  'grita llora grita',
#  'hermano desastroso grita',
#  'hermano autor alguien expresa demandante',
#  'hermano grita pelota(salta bota',
#  'escandaloso',
#  'hermano grita',
#  'molesta facilmente',
#  'hermano grita',
#  'hermano grita',
#  'pega gritos',
#  'persona grita',
#  'hermano grita',
#  'alguien gritar',
#  'hermanos gritan lloran menores casas comparo pelota',
#  'that maybe her sister always screams to her',
#  'bebe grita',
#  'gritando',
#  'deja gritar',
#  'hermanito grita',
#  'significar hermano ruidoso',
#  'grita',
#  'usando palabra pelota ue pensar hermanito simplemente griton',
#  'nino grita']

# %%
nlp = spacy.load("./model")

# %%
def similitud_spacy(docs, frase):
    """
    Toma una lista de strings y compara cada string
    con la frase modelo, genera un lista con los resultados
    y la regresa. Para mejores resultados al comparar, limpiar
    la frase modelo y la lista de strings usando la funcion
    clean_docs()
    """
    frase = nlp(frase)
    resultados = [nlp(sim).similarity(frase) for sim in docs]
    return resultados

# %% [markdown]
# #### Generamos el dataframe con los resultados

# %%
resultados = pd.DataFrame({
    model_str : docs_str,
    "limpio" : docs,
    "similarity" : similarities,
    "wmdistances" : wmdistances,
    "n_similarities" : n_similarities,
    "distance" : distances
    "spacy" : similitud_spacy(clean_doc_str, model_str)
})

# %% [markdown]
# #### Guardamos el dataframe

# %%
resultados.to_csv("resultados.csv")
